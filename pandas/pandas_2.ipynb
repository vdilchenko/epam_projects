# %%
import psycopg2
import pandas as pd

# %%
conn = psycopg2.connect(dbname='postgres', user='ilchenkoslava')
cur = conn.cursor()

# %% [markdown]
# ## CSV to DB, Pandas DF

# %%
# %%time
cur.execute("""
        CREATE TABLE IF NOT EXISTS consumer_complaints(
        date_received date not null,
        product_name text not null,
        sub_product text,
        issue text not null,
        sub_issue text,
        consumer_complaint_narrative text,
        company_public_response text,
        company text not null,
        state_name varchar(2),
        zip_code varchar(10),
        tags text,
        consumer_consent_provided varchar(30),
        CHECK (consumer_consent_provided in ('', 'N/A', 'Consent provided', 'Consent not provided', 'Other')),
        submitted_via text not null,
        date_sent_to_company date not null,
        company_response_to_consumer varchar(35),
        CHECK (company_response_to_consumer in ('', 'Closed with explanation', 'Closed', 'Closed with monetary relief', 'Closed with non-monetary relief', 'Untimely response')),
        timely_response varchar(3) CHECK (timely_response in ('Yes', 'No', '')),
        consumer_disputed varchar(3) CHECK (consumer_disputed in ('Yes', 'No', '')),
        complaint_id serial,
        CONSTRAINT pk_consumer_complaint PRIMARY KEY (complaint_id)
    )
""")
conn.commit()

sql = "COPY consumer_complaints FROM STDIN DELIMITER ',' CSV HEADER"
with open('P9-ConsumerComplaints.csv', "r") as f:
    cur.copy_expert(sql, f)
conn.commit()
# Out:
# CPU times: user 52 ms, sys: 49.7 ms, total: 102 ms
# Wall time: 1.12 s

# %%
# %%time
cur.execute("""
        CREATE TABLE IF NOT EXISTS consumer_complaints(
        date_received date not null,
        product_name text not null,
        sub_product text,
        issue text not null,
        sub_issue text,
        consumer_complaint_narrative text,
        company_public_response text,
        company text not null,
        state_name varchar(2),
        zip_code varchar(10),
        tags text,
        consumer_consent_provided varchar(30),
        CHECK (consumer_consent_provided in ('', 'N/A', 'Consent provided', 'Consent not provided', 'Other')),
        submitted_via text not null,
        date_sent_to_company date not null,
        company_response_to_consumer varchar(35),
        CHECK (company_response_to_consumer in ('', 'Closed with explanation', 'Closed', 'Closed with monetary relief', 'Closed with non-monetary relief', 'Untimely response')),
        timely_response varchar(3) CHECK (timely_response in ('Yes', 'No', '')),
        consumer_disputed varchar(3) CHECK (consumer_disputed in ('Yes', 'No', '')),
        complaint_id serial,
        CONSTRAINT pk_consumer_complaint PRIMARY KEY (complaint_id)
    )
    """)
conn.commit()

sql = "COPY consumer_complaints FROM STDIN DELIMITER ',' CSV HEADER"
with open('P9-ConsumerComplaints.csv', "r") as f:
    cur.copy_expert(sql, f)
conn.commit()
# Out:
# CPU times: user 49.7 ms, sys: 45 ms, total: 94.7 ms
# Wall time: 1.3 s

# %%
# %%time
df1 = pd.read_csv('P9-ConsumerComplaints.csv')
# Out:
# CPU times: user 197 ms, sys: 37.7 ms, total: 235 ms
# Wall time: 234 ms
# <decorator-gen-54>:2: DtypeWarning: Columns (5,11) have mixed types.Specify dtype option on import or set low_memory=False.

# %%
# %%time
df2 = pd.read_sql('SELECT * from consumer_complaints', conn)
# Out:
# CPU times: user 340 ms, sys: 29.9 ms, total: 370 ms
# Wall time: 410 ms

# %% [markdown]
# ## Select from DB, Pandas

# %%
from datetime import datetime

# %%
start_date = datetime(2013, 7, 20)
end_date = datetime(2013, 8, 25)

# %%
# %%time
cur.execute("""
        SELECT 
            product_name, 
            count(issue) issues,
            count(issue) filter (where timely_response = 'Yes') as issues_done_timely,
            count(issue) filter (where consumer_disputed = 'Yes') as issues_disputed
        from consumer_complaints 
        where date_received >= '{}' and date_received <= '{}'
        group by product_name
        order by issues desc
""".format(start_date, end_date))

rows = cur.fetchall()
print("Product name | issues | issues_done_timely | issues_disputed")
for row in rows:
    print(row[0], row[1], row[2], row[3])
# Out:
# Product name | issues | issuesd_done_timely | issues_disputed
# Mortgage 1189 1176 287
# Debt collection 368 353 72
# Credit reporting 346 346 62
# Credit card 333 333 86
# Bank account or service 327 321 67
# Consumer Loan 71 71 21
# Student loan 62 62 11
# Money transfers 13 13 3
# CPU times: user 1.24 ms, sys: 1.53 ms, total: 2.77 ms
# Wall time: 9.42 ms

# %%
df1['Date Received'] = pd.to_datetime(df1['Date Received'])

# %%
df1.head()
# Out:
#   Date Received             Product Name                  Sub Product  \
# 0    2013-07-29            Consumer Loan                 Vehicle loan
# 1    2013-07-29  Bank account or service             Checking account
# 2    2013-07-29  Bank account or service             Checking account
# 3    2013-07-29  Bank account or service             Checking account
# 4    2013-07-29                 Mortgage  Conventional fixed mortgage
#
#                                       Issue Sub Issue  \
# 0                Managing the loan or lease       NaN
# 1                 Using a debit or ATM card       NaN
# 2   Account opening, closing, or management       NaN
# 3                  Deposits and withdrawals       NaN
# 4  Loan servicing, payments, escrow account       NaN
#
#   Consumer Complaint Narrative Company Public Response  \
# 0                          NaN                     NaN
# 1                          NaN                     NaN
# 2                          NaN                     NaN
# 3                          NaN                     NaN
# 4                          NaN                     NaN
#
#                       Company State Name Zip Code            Tags  \
# 0       Wells Fargo & Company         VA    24540             NaN
# 1       Wells Fargo & Company         CA    95992  Older American
# 2           Santander Bank US         NY    10065             NaN
# 3       Wells Fargo & Company         GA    30084             NaN
# 4  Franklin Credit Management         CT     6106             NaN
#
#   Consumer Consent Provided Submitted via Date Sent to Company  \
# 0                       NaN         Phone           2013-07-30
# 1                       NaN           Web           2013-07-31
# 2                       NaN           Fax           2013-07-31
# 3                       NaN           Web           2013-07-30
# 4                       NaN           Web           2013-07-30
#
#   Company Response to Consumer Timely Response Consumer Disputed  Complaint ID
# 0      Closed with explanation             Yes                No        468882
# 1      Closed with explanation             Yes                No        468889
# 2                       Closed             Yes                No        468879
# 3      Closed with explanation             Yes                No        468949
# 4      Closed with explanation             Yes                No        475823

# %%
# %%time
df3 = df1[(start_date <= df1['Date Received']) & (df1['Date Received'] <= end_date)]
df4 = pd.DataFrame()
df4['Issues'] = df3.groupby(['Product Name'])['Issue'].count()
df4['Issues Done Timely'] = df3[df3['Timely Response'] == 'Yes'].groupby(['Product Name'])['Issue'].count()
df4['Issues Disputed'] = df3[df3['Consumer Disputed'] == 'Yes'].groupby(['Product Name'])['Issue'].count()
print(df4)
# Out:
#                          Issues  Issues Done Timely  Issues Disputed
# Product Name
# Bank account or service     327                 321               67
# Consumer Loan                71                  71               21
# Credit card                 333                 333               86
# Credit reporting            346                 346               62
# Debt collection             368                 353               72
# Money transfers              13                  13                3
# Mortgage                   1189                1176              287
# Student loan                 62                  62               11
# CPU times: user 11 ms, sys: 1.74 ms, total: 12.8 ms
# Wall time: 11.2 ms

# %%
print(df1['Company'].unique())
# Out:
# ['Wells Fargo & Company' 'Santander Bank US' 'Franklin Credit Management'
#  ... '24 Asset Management Corp' 'Century Financial Services, Inc.'
#  'Advanced Call Center Technologies, LLC']

# %%
company = 'Wells Fargo & Company'
fetch_all = True

# %%
# %%time
cur.execute("""
        with max_issues_state as (
            select state_name, count(issue) amount_issues
            from consumer_complaints
            where company = '{0}' and state_name is not null
            group by state_name
            order by amount_issues desc
            limit 1)
        select * from consumer_complaints
        where company = '{0}' and state_name = (select state_name from max_issues_state)
""".format(company))

if(fetch_all):
    rows = cur.fetchall()
else:
    rows = cur.fetchmany(size)

colnames = [desc[0] for desc in cur.description]
print(' | '.join(colnames))
for row in rows:
    print(row)
# Out:
# date_received | product_name | sub_product | issue | sub_issue | consumer_complaint_narrative | company_public_response | company | state_name | zip_code | tags | consumer_consent_provided | submitted_via | date_sent_to_company | company_response_to_consumer | timely_response | consumer_disputed | complaint_id
# (datetime.date(2013, 7, 29), 'Bank account or service', 'Checking account', 'Using a debit or ATM card', None, None, None, 'Wells Fargo & Company', 'CA', '95992', 'Older American', 'N/A', 'Web', datetime.date(2013, 7, 31), 'Closed with explanation', 'Yes', 'No', 468889)
# (datetime.date(2013, 7, 29), 'Bank account or service', 'Other bank product/service', 'Deposits and withdrawals', None, None, None, 'Wells Fargo & Company', 'CA', '96088', None, 'N/A', 'Web', datetime.date(2013, 8, 1), 'Closed with explanation', 'Yes', 'No', 469185)
# (datetime.date(2013, 7, 29), 'Bank account or service', 'Checking account', 'Deposits and withdrawals', None, None, None, 'Wells Fargo & Company', 'CA', '92277', None, 'N/A', 'Web', datetime.date(2013, 8, 5), 'Closed with explanation', 'Yes', 'No', 469446)
# (datetime.date(2013, 7, 29), 'Mortgage', 'Conventional fixed mortgage', 'Loan modification,collection,foreclosure', None, None, None, 'Wells Fargo & Company', 'CA', '91741', None, 'N/A', 'Phone', datetime.date(2013, 7, 30), 'Closed with explanation', 'Yes', 'No', 464039)
# (datetime.date(2013, 7, 29), 'Mortgage', 'Other mortgage', 'Loan modification,collection,foreclosure', None, None, None, 'Wells Fargo & Company', 'CA', '95020', None, 'N/A', 'Referral', datetime.date(2013, 7, 31), 'Closed with explanation', 'Yes', 'No', 469660)
# (datetime.date(2013, 7, 30), 'Credit card', None, 'Credit determination', None, None, None, 'Wells Fargo & Company', 'CA', '95409', 'Older American', 'N/A', 'Web', datetime.date(2013, 7, 29), 'Closed with explanation', 'Yes', 'No', 469738)
# (datetime.date(2013, 7, 30), 'Mortgage', 'Other mortgage', 'Loan modification,collection,foreclosure', None, None, None, 'Wells Fargo & Company', 'CA', '93111', None, 'N/A', 'Referral', datetime.date(2013, 7, 31), 'Closed with explanation', 'Yes', 'No', 470103)
# (datetime.date(2013, 7, 31), 'Mortgage', 'Other mortgage', 'Loan modification,collection,foreclosure', None, None, None, 'Wells Fargo & Company', 'CA', '95117', None, 'N/A', 'Postal mail', datetime.date(2013, 8, 5), 'Closed with explanation', 'Yes', 'No', 471037)
# (datetime.date(2013, 7, 31), 'Bank account or service', 'Savings account', 'Account opening, closing, or management', None, None, None, 'Wells Fargo & Company', 'CA', '91214', 'Older American', 'N/A', 'Web', datetime.date(2013, 8, 2), 'Closed with explanation', 'Yes', 'No', 471075)
# (datetime.date(2013, 7, 31), 'Consumer Loan', 'Vehicle loan', 'Problems when you are unable to pay', None, None, None, 'Wells Fargo & Company', 'CA', '90404', None, 'N/A', 'Referral', datetime.date(2013, 8, 5), 'Closed with monetary relief', 'Yes', 'No', 471379)
# (datetime.date(2013, 7, 31), 'Mortgage', 'Other mortgage', 'Loan modification,collection,foreclosure', None, None, None, 'Wells Fargo & Company', 'CA', '91359', None, 'N/A', 'Referral', datetime.date(2013, 8, 2), 'Closed with explanation', 'Yes', 'No', 471391)
# (datetime.date(2013, 7, 22), 'Bank account or service', 'Other bank product/service', 'Account opening, closing, or management', None, None, None, 'Wells Fargo & Company', 'CA', '95376', None, 'N/A', 'Phone', datetime.date(2013, 7, 30), 'Closed with explanation', 'Yes', 'No', 463525)
# (datetime.date(2013, 7, 31), 'Mortgage', 'Other mortgage', 'Loan modification,collection,foreclosure', None, None, None, 'Wells Fargo & Company', 'CA', '91364', None, 'N/A', 'Referral', datetime.date(2013, 8, 5), 'Closed with explanation', 'Yes', 'No', 471328)
# (datetime.date(2013, 8, 6), 'Mortgage', 'Conventional fixed mortgage', 'Loan modification,collection,foreclosure', None, None, None, 'Wells Fargo & Company', 'CA', '92626', None, 'N/A', 'Web', datetime.date(2013, 8, 8), 'Closed with explanation', 'Yes', 'No', 482132)
# (datetime.date(2013, 8, 1), 'Bank account or service', 'Checking account', 'Deposits and withdrawals', None, None, None, 'Wells Fargo & Company', 'CA', '95348', None, 'N/A', 'Web', datetime.date(2013, 8, 2), 'Closed with monetary relief', 'Yes', 'No', 471471)
# (datetime.date(2013, 7, 23), 'Mortgage', 'Other mortgage', 'Loan modification,collection,foreclosure', None, None, None, 'Wells Fargo & Company', 'CA', '90069', None, 'N/A', 'Referral', datetime.date(2013, 7, 24), 'Closed with monetary relief', 'Yes', 'No', 463685)
# (datetime.date(2013, 8, 6), 'Mortgage', 'Conventional adjustable mortgage (ARM)', 'Loan modification,collection,foreclosure', None, None, None, 'Wells Fargo & Company', 'CA', '92626', None, 'N/A', 'Web', datetime.date(2013, 8, 13), 'Closed with explanation', 'Yes', 'No', 482133)
# (datetime.date(2013, 7, 24), 'Mortgage', 'Other mortgage', 'Loan modification,collection,foreclosure', None, None, None, 'Wells Fargo & Company', 'CA', '92660', None, 'N/A', 'Referral', datetime.date(2013, 7, 26), 'Closed with explanation', 'Yes', 'No', 476088)
# (datetime.date(2013, 7, 24), 'Bank account or service', 'Checking account', 'Account opening, closing, or management', None, None, None, 'Wells Fargo & Company', 'CA', '92651', None, 'N/A', 'Web', datetime.date(2013, 7, 24), 'Closed with explanation', 'Yes', 'No', 463657)
# (datetime.date(2013, 8, 13), 'Bank account or service', 'Other bank product/service', 'Deposits and withdrawals', None, None, None, 'Wells Fargo & Company', 'CA', '94704', None, 'N/A', 'Fax', datetime.date(2013, 8, 15), 'Closed with explanation', 'Yes', 'No', 489061)
# (datetime.date(2013, 8, 7), 'Mortgage', 'Other mortgage', 'Loan modification,collection,foreclosure', None, None, None, 'Wells Fargo & Company', 'CA', '94503', None, 'N/A', 'Web', datetime.date(2013, 8, 7), 'Closed with explanation', 'Yes', 'Yes', 482927)
# (datetime.date(2013, 7, 24), 'Mortgage', 'Other mortgage', 'Loan modification,collection,foreclosure', None, None, None, 'Wells Fargo & Company', 'CA', '94534', None, 'N/A', 'Referral', datetime.date(2013, 7, 26), 'Closed with explanation', 'Yes', 'Yes', 465834)
# (datetime.date(2013, 7, 23), 'Mortgage', 'Other mortgage', 'Loan modification,collection,foreclosure', None, None, None, 'Wells Fargo & Company', 'CA', '90706', None, 'N/A', 'Referral', datetime.date(2013, 7, 25), 'Closed with explanation', 'Yes', 'Yes', 455806)
# (datetime.date(2013, 8, 7), 'Bank account or service', 'Other bank product/service', 'Account opening, closing, or management', None, None, None, 'Wells Fargo & Company', 'CA', '94901', None, 'N/A', 'Referral', datetime.date(2013, 8, 9), 'Closed with explanation', 'Yes', 'No', 483016)
# (datetime.date(2013, 7, 24), 'Mortgage', 'Other mortgage', 'Loan modification,collection,foreclosure', None, None, None, 'Wells Fargo & Company', 'CA', '93010', None, 'N/A', 'Referral', datetime.date(2013, 7, 25), 'Closed with explanation', 'Yes', 'No', 465102)
# (datetime.date(2013, 7, 24), 'Mortgage', 'Other mortgage', 'Loan modification,collection,foreclosure', None, None, None, 'Wells Fargo & Company', 'CA', '91724', None, 'N/A', 'Referral', datetime.date(2013, 7, 25), 'Closed with explanation', 'Yes', 'Yes', 465513)
# (datetime.date(2013, 7, 24), 'Mortgage', 'Other mortgage', 'Loan modification,collection,foreclosure', None, None, None, 'Wells Fargo & Company', 'CA', '91387', None, 'N/A', 'Referral', datetime.date(2013, 7, 29), 'Closed with explanation', 'Yes', 'Yes', 465556)
# (datetime.date(2013, 7, 25), 'Mortgage', 'Other mortgage', 'Loan modification,collection,foreclosure', None, None, None, 'Wells Fargo & Company', 'CA', '92881', None, 'N/A', 'Referral', datetime.date(2013, 7, 26), 'Closed with explanation', 'Yes', 'No', 476055)
# (datetime.date(2013, 7, 25), 'Mortgage', 'Other mortgage', 'Loan modification,collection,foreclosure', None, None, None, 'Wells Fargo & Company', 'CA', '90010', None, 'N/A', 'Referral', datetime.date(2013, 7, 29), 'Closed with explanation', 'Yes', 'Yes', 462190)
# (datetime.date(2013, 8, 21), 'Mortgage', 'Home equity loan or line of credit', 'Settlement process and costs', None, None, None, 'Wells Fargo & Company', 'CA', '92591', None, 'N/A', 'Web', datetime.date(2013, 8, 23), 'Closed with explanation', 'Yes', 'Yes', 499520)
# (datetime.date(2013, 8, 8), 'Mortgage', 'Other mortgage', 'Loan modification,collection,foreclosure', None, None, None, 'Wells Fargo & Company', 'CA', '91367', None, 'N/A', 'Referral', datetime.date(2013, 8, 13), 'Closed with explanation', 'Yes', 'No', 483552)
# (datetime.date(2013, 7, 26), 'Mortgage', 'Other mortgage', 'Loan modification,collection,foreclosure', None, None, None, 'Wells Fargo & Company', 'CA', '95376', None, 'N/A', 'Referral', datetime.date(2013, 7, 29), 'Closed with explanation', 'Yes', 'Yes', 468023)
# (datetime.date(2013, 8, 8), 'Consumer Loan', 'Vehicle loan', 'Managing the loan or lease', None, None, None, 'Wells Fargo & Company', 'CA', '92071', None, 'N/A', 'Web', datetime.date(2013, 8, 9), 'Closed with explanation', 'Yes', 'No', 483604)
# (datetime.date(2013, 8, 2), 'Bank account or service', 'Other bank product/service', 'Making/receiving payments, sending money', None, None, None, 'Wells Fargo & Company', 'CA', '92706', None, 'N/A', 'Web', datetime.date(2013, 8, 7), 'Closed with monetary relief', 'Yes', 'No', 472434)
# (datetime.date(2013, 8, 15), 'Mortgage', 'Other mortgage', 'Loan modification,collection,foreclosure', None, None, None, 'Wells Fargo & Company', 'CA', '91344', None, 'N/A', 'Referral', datetime.date(2013, 8, 16), 'Closed with explanation', 'Yes', 'No', 490389)
# (datetime.date(2013, 8, 3), 'Mortgage', 'Conventional fixed mortgage', 'Application, originator, mortgage broker', None, None, None, 'Wells Fargo & Company', 'CA', '91303', 'Older American', 'N/A', 'Web', datetime.date(2013, 8, 6), 'Closed with explanation', 'Yes', 'No', 481086)
# (datetime.date(2013, 8, 15), 'Mortgage', 'Other mortgage', 'Loan servicing, payments, escrow account', None, None, None, 'Wells Fargo & Company', 'CA', '90703', None, 'N/A', 'Postal mail', datetime.date(2013, 8, 16), 'Closed with monetary relief', 'Yes', 'No', 489892)
# (datetime.date(2013, 7, 26), 'Bank account or service', 'Other bank product/service', 'Account opening, closing, or management', None, None, None, 'Wells Fargo & Company', 'CA', '94931', None, 'N/A', 'Phone', datetime.date(2013, 8, 1), 'Closed with explanation', 'Yes', 'No', 468190)
# (datetime.date(2013, 7, 26), 'Mortgage', 'Other mortgage', 'Loan modification,collection,foreclosure', None, None, None, 'Wells Fargo & Company', 'CA', '94566', None, 'N/A', 'Referral', datetime.date(2013, 7, 30), 'Closed with explanation', 'Yes', 'No', 454622)
# (datetime.date(2013, 8, 22), 'Mortgage', 'Other mortgage', 'Loan modification,collection,foreclosure', None, None, None, 'Wells Fargo & Company', 'CA', '92780', None, 'N/A', 'Referral', datetime.date(2013, 8, 23), 'Closed with explanation', 'Yes', 'No', 500081)
# (datetime.date(2013, 8, 9), 'Mortgage', 'Conventional fixed mortgage', 'Loan servicing, payments, escrow account', None, None, None, 'Wells Fargo & Company', 'CA', '95615', None, 'N/A', 'Web', datetime.date(2013, 8, 12), 'Closed with explanation', 'Yes', 'Yes', 485216)
# (datetime.date(2013, 8, 9), 'Mortgage', 'Other mortgage', 'Other', None, None, None, 'Wells Fargo & Company', 'CA', '90660', None, 'N/A', 'Referral', datetime.date(2013, 8, 13), 'Closed with explanation', 'Yes', 'No', 485806)
# (datetime.date(2013, 8, 2), 'Mortgage', 'Conventional fixed mortgage', 'Loan modification,collection,foreclosure', None, None, None, 'Wells Fargo & Company', 'CA', '92101', None, 'N/A', 'Web', datetime.date(2013, 8, 6), 'Closed with explanation', 'Yes', 'No', 474973)
# (datetime.date(2013, 8, 2), 'Mortgage', 'Conventional fixed mortgage', 'Loan modification,collection,foreclosure', None, None, None, 'Wells Fargo & Company', 'CA', '95843', None, 'N/A', 'Phone', datetime.date(2013, 8, 22), 'Closed with explanation', 'Yes', 'Yes', 473284)
# (datetime.date(2013, 8, 3), 'Mortgage', 'Conventional fixed mortgage', 'Settlement process and costs', None, None, None, 'Wells Fargo & Company', 'CA', '94519', 'Older American', 'N/A', 'Web', datetime.date(2013, 8, 6), 'Closed with explanation', 'Yes', 'No', 473396)
# (datetime.date(2013, 8, 23), 'Mortgage', 'Conventional fixed mortgage', 'Loan modification,collection,foreclosure', None, None, None, 'Wells Fargo & Company', 'CA', '94560', None, 'N/A', 'Web', datetime.date(2013, 8, 23), 'Closed with explanation', 'Yes', 'No', 501990)
# (datetime.date(2013, 8, 16), 'Mortgage', 'Other mortgage', 'Loan servicing, payments, escrow account', None, None, None, 'Wells Fargo & Company', 'CA', '94112', 'Older American', 'N/A', 'Referral', datetime.date(2013, 8, 20), 'Closed with explanation', 'Yes', 'Yes', 493087)
# (datetime.date(2013, 8, 16), 'Credit card', None, 'Other', None, None, None, 'Wells Fargo & Company', 'CA', '94605', None, 'N/A', 'Phone', datetime.date(2013, 8, 22), 'Closed with explanation', 'Yes', 'No', 493574)
# (datetime.date(2013, 8, 12), 'Bank account or service', 'Checking account', 'Deposits and withdrawals', None, None, None, 'Wells Fargo & Company', 'CA', '91331', None, 'N/A', 'Web', datetime.date(2013, 8, 14), 'Closed with explanation', 'Yes', 'Yes', 487109)
# (datetime.date(2013, 8, 29), 'Mortgage', 'Other mortgage', 'Credit decision / Underwriting', None, None, None, 'Wells Fargo & Company', 'CA', '94404', None, 'N/A', 'Postal mail', datetime.date(2013, 9, 3), 'Closed with explanation', 'Yes', 'No', 509195)
# (datetime.date(2013, 8, 12), 'Consumer Loan', 'Vehicle loan', 'Managing the loan or lease', None, None, None, 'Wells Fargo & Company', 'CA', '94925', None, 'N/A', 'Referral', datetime.date(2013, 8, 13), 'Closed with explanation', 'Yes', 'No', 487575)
# (datetime.date(2013, 8, 16), 'Consumer Loan', 'Vehicle loan', 'Shopping for a loan or lease', None, None, None, 'Wells Fargo & Company', 'CA', '95126', None, 'N/A', 'Web', datetime.date(2013, 8, 20), 'Closed with explanation', 'Yes', 'Yes', 493653)
# (datetime.date(2013, 9, 5), 'Bank account or service', 'Cashing a check without an account', 'Deposits and withdrawals', None, None, None, 'Wells Fargo & Company', 'CA', '95319', None, 'N/A', 'Postal mail', datetime.date(2013, 9, 6), 'Closed with explanation', 'Yes', 'Yes', 516312)
# (datetime.date(2013, 8, 24), 'Mortgage', 'Other mortgage', 'Loan servicing, payments, escrow account', None, None, None, 'Wells Fargo & Company', 'CA', '94080', None, 'N/A', 'Referral', datetime.date(2013, 8, 26), 'Closed with explanation', 'Yes', 'No', 503295)
# (datetime.date(2013, 8, 17), 'Mortgage', 'Other mortgage', 'Loan modification,collection,foreclosure', None, None, None, 'Wells Fargo & Company', 'CA', '92113', None, 'N/A', 'Postal mail', datetime.date(2013, 8, 19), 'Closed with explanation', 'Yes', 'No', 494446)
# (datetime.date(2013, 8, 17), 'Mortgage', 'VA mortgage', 'Loan modification,collection,foreclosure', None, None, None, 'Wells Fargo & Company', 'CA', '92395', None, 'N/A', 'Postal mail', datetime.date(2013, 8, 19), 'Closed with explanation', 'Yes', 'No', 494521)
# (datetime.date(2013, 8, 25), 'Mortgage', 'Other mortgage', 'Loan modification,collection,foreclosure', None, None, None, 'Wells Fargo & Company', 'CA', '95354', None, 'N/A', 'Postal mail', datetime.date(2013, 8, 26), 'Closed with explanation', 'Yes', 'No', 501642)
# (datetime.date(2013, 9, 5), 'Mortgage', 'Conventional adjustable mortgage (ARM)', 'Loan servicing, payments, escrow account', None, None, None, 'Wells Fargo & Company', 'CA', '94558', None, 'N/A', 'Web', datetime.date(2013, 9, 6), 'Closed with explanation', 'Yes', 'Yes', 514992)
# (datetime.date(2013, 8, 30), 'Money transfers', 'International money transfer', 'Incorrect/missing disclosures or info', None, None, None, 'Wells Fargo & Company', 'CA', '92009', 'Older American', 'N/A', 'Web', datetime.date(2013, 8, 29), 'Closed with explanation', 'Yes', 'No', 510341)
# (datetime.date(2013, 8, 30), 'Mortgage', 'Other mortgage', 'Loan modification,collection,foreclosure', None, None, None, 'Wells Fargo & Company', 'CA', '31328', None, 'N/A', 'Referral', datetime.date(2013, 9, 3), 'Closed with explanation', 'Yes', 'No', 509963)
# (datetime.date(2013, 8, 12), 'Mortgage', 'Conventional adjustable mortgage (ARM)', 'Loan modification,collection,foreclosure', None, None, None, 'Wells Fargo & Company', 'CA', '90638', 'Older American', 'N/A', 'Web', datetime.date(2013, 8, 14), 'Closed with explanation', 'Yes', 'No', 488565)
# (datetime.date(2013, 9, 17), 'Bank account or service', 'Checking account', 'Account opening, closing, or management', None, None, None, 'Wells Fargo & Company', 'CA', '90212', None, 'N/A', 'Web', datetime.date(2013, 9, 18), 'Closed with explanation', 'Yes', 'No', 531051)
# (datetime.date(2013, 9, 6), 'Bank account or service', 'Checking account', 'Deposits and withdrawals', None, None, None, 'Wells Fargo & Company', 'CA', '91786', None, 'N/A', 'Web', datetime.date(2013, 9, 6), 'Closed with explanation', 'Yes', 'Yes', 517900)
# (datetime.date(2013, 9, 12), 'Bank account or service', 'Checking account', 'Account opening, closing, or management', None, None, None, 'Wells Fargo & Company', 'CA', '95687', None, 'N/A', 'Referral', datetime.date(2013, 9, 13), 'Closed with explanation', 'Yes', 'No', 524530)
# (datetime.date(2013, 9, 12), 'Bank account or service', 'Checking account', 'Account opening, closing, or management', None, None, None, 'Wells Fargo & Company', 'CA', '93065', None, 'N/A', 'Referral', datetime.date(2013, 9, 12), 'Closed with monetary relief', 'Yes', 'No', 525162)
# (datetime.date(2013, 9, 6), 'Mortgage', 'Conventional adjustable mortgage (ARM)', 'Loan modification,collection,foreclosure', None, None, None, 'Wells Fargo & Company', 'CA', '94928', None, 'N/A', 'Phone', datetime.date(2013, 9, 18), 'Closed with explanation', 'Yes', 'No', 518441)
# (datetime.date(2013, 9, 18), 'Mortgage', 'Other mortgage', 'Loan modification,collection,foreclosure', None, None, None, 'Wells Fargo & Company', 'CA', '91744', None, 'N/A', 'Web', datetime.date(2013, 9, 19), 'Closed with explanation', 'Yes', 'No', 532483)
# (datetime.date(2013, 9, 12), 'Mortgage', 'Conventional fixed mortgage', 'Application, originator, mortgage broker', None, None, None, 'Wells Fargo & Company', 'CA', '95965', 'Servicemember', 'N/A', 'Phone', datetime.date(2013, 9, 13), 'Closed with explanation', 'Yes', 'No', 524586)
# (datetime.date(2013, 9, 12), 'Bank account or service', 'Checking account', 'Problems caused by my funds being low', None, None, None, 'Wells Fargo & Company', 'CA', '95354', None, 'N/A', 'Referral', datetime.date(2013, 9, 16), 'Closed with explanation', 'Yes', 'No', 525705)
# (datetime.date(2013, 8, 30), 'Mortgage', 'Other mortgage', 'Loan servicing, payments, escrow account', None, None, None, 'Wells Fargo & Company', 'CA', '91104', None, 'N/A', 'Referral', datetime.date(2013, 9, 3), 'Closed with explanation', 'Yes', 'Yes', 511080)
# (datetime.date(2013, 9, 19), 'Consumer Loan', 'Vehicle loan', 'Problems when you are unable to pay', None, None, None, 'Wells Fargo & Company', 'CA', '92567', None, 'N/A', 'Web', datetime.date(2013, 9, 19), 'Closed with explanation', 'Yes', 'Yes', 533811)
# (datetime.date(2013, 9, 3), 'Mortgage', 'Conventional fixed mortgage', 'Loan modification,collection,foreclosure', None, None, None, 'Wells Fargo & Company', 'CA', '92626', None, 'N/A', 'Web', datetime.date(2013, 9, 3), 'Closed with non-monetary relief', 'Yes', 'No', 511879)
# (datetime.date(2013, 9, 9), 'Mortgage', 'Other mortgage', 'Loan modification,collection,foreclosure', None, None, None, 'Wells Fargo & Company', 'CA', '92376', None, 'N/A', 'Referral', datetime.date(2013, 9, 10), 'Closed with explanation', 'Yes', 'No', 520468)
# (datetime.date(2013, 9, 9), 'Bank account or service', 'Checking account', 'Using a debit or ATM card', None, None, None, 'Wells Fargo & Company', 'CA', '93033', None, 'N/A', 'Phone', datetime.date(2013, 9, 10), 'Closed with explanation', 'Yes', 'No', 520445)
# (datetime.date(2013, 9, 12), 'Mortgage', 'Conventional adjustable mortgage (ARM)', 'Loan modification,collection,foreclosure', None, None, None, 'Wells Fargo & Company', 'CA', '94531', 'Older American', 'N/A', 'Phone', datetime.date(2013, 9, 13), 'Closed with explanation', 'Yes', 'No', 526084)
# (datetime.date(2013, 8, 26), 'Mortgage', 'Other mortgage', 'Loan modification,collection,foreclosure', None, None, None, 'Wells Fargo & Company', 'CA', '95316', None, 'N/A', 'Referral', datetime.date(2013, 8, 28), 'Closed with explanation', 'Yes', 'No', 504260)
# (datetime.date(2013, 8, 26), 'Mortgage', 'Second mortgage', 'Loan modification,collection,foreclosure', None, None, None, 'Wells Fargo & Company', 'CA', '93635', None, 'N/A', 'Referral', datetime.date(2013, 8, 27), 'Closed with explanation', 'Yes', 'No', 503388)
# (datetime.date(2013, 9, 19), 'Mortgage', 'Conventional fixed mortgage', 'Loan modification,collection,foreclosure', None, None, None, 'Wells Fargo & Company', 'CA', '92590', None, 'N/A', 'Web', datetime.date(2013, 9, 23), 'Closed with explanation', 'Yes', 'No', 535182)
# (datetime.date(2013, 9, 20), 'Mortgage', 'Conventional fixed mortgage', 'Loan modification,collection,foreclosure', None, None, None, 'Wells Fargo & Company', 'CA', '95350', None, 'N/A', 'Web', datetime.date(2013, 9, 26), 'Closed with explanation', 'Yes', 'Yes', 535791)
# (datetime.date(2013, 9, 4), 'Consumer Loan', 'Vehicle loan', 'Taking out the loan or lease', None, None, None, 'Wells Fargo & Company', 'CA', '92530', None, 'N/A', 'Web', datetime.date(2013, 9, 4), 'Closed with explanation', 'Yes', 'No', 513716)
# (datetime.date(2013, 8, 27), 'Mortgage', 'Other mortgage', 'Loan modification,collection,foreclosure', None, None, None, 'Wells Fargo & Company', 'CA', '91345', None, 'N/A', 'Referral', datetime.date(2013, 8, 28), 'Closed with explanation', 'Yes', 'No', 505326)
# (datetime.date(2013, 8, 27), 'Bank account or service', 'Checking account', 'Making/receiving payments, sending money', None, None, None, 'Wells Fargo & Company', 'CA', '94556', 'Older American', 'N/A', 'Postal mail', datetime.date(2013, 10, 17), 'Closed with explanation', 'Yes', 'Yes', 501892)
# (datetime.date(2013, 8, 27), 'Mortgage', 'Home equity loan or line of credit', 'Loan servicing, payments, escrow account', None, None, None, 'Wells Fargo & Company', 'CA', '95032', None, 'N/A', 'Referral', datetime.date(2013, 8, 28), 'Closed with explanation', 'Yes', 'No', 505690)
# (datetime.date(2013, 10, 1), 'Mortgage', 'FHA mortgage', 'Loan modification,collection,foreclosure', None, None, None, 'Wells Fargo & Company', 'CA', '95386', None, 'N/A', 'Phone', datetime.date(2013, 10, 2), 'Closed with explanation', 'Yes', 'No', 549662)
# (datetime.date(2013, 9, 14), 'Mortgage', 'Conventional adjustable mortgage (ARM)', 'Loan modification,collection,foreclosure', None, None, None, 'Wells Fargo & Company', 'CA', '94520', None, 'N/A', 'Web', datetime.date(2013, 9, 16), 'Closed with explanation', 'Yes', 'No', 526365)
# (datetime.date(2013, 9, 14), 'Bank account or service', 'Savings account', 'Deposits and withdrawals', None, None, None, 'Wells Fargo & Company', 'CA', '94804', 'Older American', 'N/A', 'Web', datetime.date(2013, 9, 16), 'Closed', 'Yes', 'No', 526379)
# (datetime.date(2013, 9, 14), 'Mortgage', 'Conventional fixed mortgage', 'Loan servicing, payments, escrow account', None, None, None, 'Wells Fargo & Company', 'CA', '94903', 'Older American', 'N/A', 'Web', datetime.date(2013, 9, 16), 'Closed with non-monetary relief', 'Yes', 'No', 526382)
# (datetime.date(2013, 9, 15), 'Debt collection', 'I do not know', 'Improper contact or sharing of info', 'Contacted me after I asked not to', None, None, 'Wells Fargo & Company', 'CA', '95632', None, 'N/A', 'Web', datetime.date(2013, 9, 17), 'Closed with non-monetary relief', 'Yes', 'No', 526429)
# (datetime.date(2013, 9, 16), 'Mortgage', 'Conventional adjustable mortgage (ARM)', 'Loan modification,collection,foreclosure', None, None, None, 'Wells Fargo & Company', 'CA', '92626', None, 'N/A', 'Web', datetime.date(2013, 9, 17), 'Closed with explanation', 'Yes', 'No', 529605)
# (datetime.date(2013, 9, 4), 'Mortgage', 'Conventional fixed mortgage', 'Loan servicing, payments, escrow account', None, None, None, 'Wells Fargo & Company', 'CA', '90301', None, 'N/A', 'Phone', datetime.date(2013, 9, 5), 'Closed with explanation', 'Yes', 'No', 514299)
# (datetime.date(2013, 10, 11), 'Mortgage', 'Other mortgage', 'Loan modification,collection,foreclosure', None, None, None, 'Wells Fargo & Company', 'CA', '92821', None, 'N/A', 'Web', datetime.date(2013, 10, 15), 'Closed with explanation', 'Yes', 'No', 558637)
# (datetime.date(2013, 9, 16), 'Credit card', None, 'Closing/Cancelling account', None, None, None, 'Wells Fargo & Company', 'CA', '91007', None, 'N/A', 'Web', datetime.date(2013, 9, 17), 'Closed with explanation', 'Yes', 'Yes', 528925)
# (datetime.date(2013, 10, 12), 'Mortgage', 'Conventional adjustable mortgage (ARM)', 'Application, originator, mortgage broker', None, None, None, 'Wells Fargo & Company', 'CA', '90706', None, 'N/A', 'Web', datetime.date(2013, 10, 15), 'Closed with explanation', 'Yes', 'Yes', 558276)
# (datetime.date(2013, 9, 4), 'Mortgage', 'Conventional adjustable mortgage (ARM)', 'Loan modification,collection,foreclosure', None, None, None, 'Wells Fargo & Company', 'CA', '94703', 'Older American', 'N/A', 'Phone', datetime.date(2013, 9, 5), 'Closed with explanation', 'Yes', 'No', 514674)
# (datetime.date(2013, 9, 16), 'Mortgage', 'Conventional adjustable mortgage (ARM)', 'Loan modification,collection,foreclosure', None, None, None, 'Wells Fargo & Company', 'CA', '92821', None, 'N/A', 'Web', datetime.date(2013, 9, 17), 'Closed with explanation', 'Yes', 'Yes', 529100)
# (datetime.date(2013, 9, 16), 'Mortgage', 'Other mortgage', 'Loan modification,collection,foreclosure', None, None, None, 'Wells Fargo & Company', 'CA', '95993', 'Servicemember', 'N/A', 'Web', datetime.date(2013, 9, 17), 'Closed with explanation', 'Yes', 'No', 529193)
# (datetime.date(2013, 9, 16), 'Bank account or service', 'Checking account', 'Account opening, closing, or management', None, None, None, 'Wells Fargo & Company', 'CA', '94507', None, 'N/A', 'Web', datetime.date(2013, 9, 17), 'Closed with explanation', 'Yes', 'No', 529222)
# (datetime.date(2013, 10, 14), 'Mortgage', 'Conventional fixed mortgage', 'Loan modification,collection,foreclosure', None, None, None, 'Wells Fargo & Company', 'CA', '92240', None, 'N/A', 'Web', datetime.date(2013, 10, 16), 'Closed with explanation', 'Yes', 'No', 558649)
# (datetime.date(2013, 9, 5), 'Mortgage', 'Other mortgage', 'Settlement process and costs', None, None, None, 'Wells Fargo & Company', 'CA', '90272', None, 'N/A', 'Web', datetime.date(2013, 9, 26), 'Closed with explanation', 'Yes', 'Yes', 516836)
# (datetime.date(2013, 9, 10), 'Bank account or service', 'Savings account', 'Deposits and withdrawals', None, None, None, 'Wells Fargo & Company', 'CA', '90815', None, 'N/A', 'Postal mail', datetime.date(2013, 9, 10), 'Closed with explanation', 'Yes', 'No', 521719)
# (datetime.date(2013, 10, 15), 'Credit card', None, 'Rewards', None, None, None, 'Wells Fargo & Company', 'CA', '92101', None, 'N/A', 'Web', datetime.date(2013, 10, 14), 'Closed with monetary relief', 'Yes', 'No', 558978)
# (datetime.date(2013, 9, 16), 'Mortgage', 'Conventional adjustable mortgage (ARM)', 'Loan modification,collection,foreclosure', None, None, None, 'Wells Fargo & Company', 'CA', '90278', None, 'N/A', 'Web', datetime.date(2013, 9, 17), 'Closed with explanation', 'Yes', 'Yes', 529592)
# (datetime.date(2013, 8, 28), 'Mortgage', 'Other mortgage', 'Loan modification,collection,foreclosure', None, None, None, 'Wells Fargo & Company', 'CA', '90601', None, 'N/A', 'Postal mail', datetime.date(2013, 8, 29), 'Closed with explanation', 'Yes', 'No', 506091)
# (datetime.date(2013, 9, 20), 'Bank account or service', 'Savings account', 'Account opening, closing, or management', None, None, None, 'Wells Fargo & Company', 'CA', '94403', None, 'N/A', 'Web', datetime.date(2013, 9, 23), 'Closed with monetary relief', 'Yes', 'No', 536599)
# (datetime.date(2013, 9, 20), 'Mortgage', 'Conventional adjustable mortgage (ARM)', 'Loan modification,collection,foreclosure', None, None, None, 'Wells Fargo & Company', 'CA', '95673', None, 'N/A', 'Web', datetime.date(2013, 9, 23), 'Closed with explanation', 'Yes', 'Yes', 537284)
# (datetime.date(2013, 9, 20), 'Bank account or service', 'Checking account', 'Problems caused by my funds being low', None, None, None, 'Wells Fargo & Company', 'CA', '92346', None, 'N/A', 'Web', datetime.date(2013, 9, 23), 'Closed with explanation', 'Yes', 'No', 536705)
# (datetime.date(2013, 9, 5), 'Mortgage', 'Other mortgage', 'Loan servicing, payments, escrow account', None, None, None, 'Wells Fargo & Company', 'CA', '92069', None, 'N/A', 'Web', datetime.date(2013, 9, 6), 'Closed with explanation', 'Yes', 'No', 516022)
# (datetime.date(2013, 9, 20), 'Credit card', None, 'Closing/Cancelling account', None, None, None, 'Wells Fargo & Company', 'CA', '90410', None, 'N/A', 'Web', datetime.date(2013, 9, 20), 'Closed with explanation', 'Yes', 'Yes', 537345)
# (datetime.date(2013, 8, 28), 'Debt collection', 'Mortgage', 'Disclosure verification of debt', 'Not given enough info to verify debt', None, None, 'Wells Fargo & Company', 'CA', '91206', None, 'N/A', 'Referral', datetime.date(2013, 8, 29), 'Closed with explanation', 'Yes', 'No', 506687)
# (datetime.date(2013, 10, 3), 'Mortgage', 'Other mortgage', 'Loan modification,collection,foreclosure', None, None, None, 'Wells Fargo & Company', 'CA', '92037', None, 'N/A', 'Referral', datetime.date(2013, 10, 3), 'Closed with explanation', 'Yes', 'No', 551651)
# (datetime.date(2013, 9, 23), 'Mortgage', 'Other mortgage', 'Loan modification,collection,foreclosure', None, None, None, 'Wells Fargo & Company', 'CA', '94086', None, 'N/A', 'Referral', datetime.date(2013, 9, 23), 'Closed with explanation', 'Yes', 'Yes', 538058)
# (datetime.date(2013, 9, 11), 'Mortgage', 'Other mortgage', 'Loan modification,collection,foreclosure', None, None, None, 'Wells Fargo & Company', 'CA', '95677', None, 'N/A', 'Referral', datetime.date(2013, 9, 13), 'Closed with explanation', 'Yes', 'No', 523076)
# (datetime.date(2013, 10, 4), 'Mortgage', 'Other mortgage', 'Loan modification,collection,foreclosure', None, None, None, 'Wells Fargo & Company', 'CA', '94553', None, 'N/A', 'Referral', datetime.date(2013, 10, 4), 'Closed with explanation', 'Yes', 'No', 552729)
# (datetime.date(2013, 10, 4), 'Bank account or service', 'Checking account', 'Account opening, closing, or management', None, None, None, 'Wells Fargo & Company', 'CA', '92223', None, 'N/A', 'Referral', datetime.date(2013, 10, 7), 'Closed with non-monetary relief', 'Yes', 'No', 552994)
# (datetime.date(2013, 9, 23), 'Credit card', None, 'Billing disputes', None, None, None, 'Wells Fargo & Company', 'CA', '94123', 'Servicemember', 'N/A', 'Phone', datetime.date(2013, 11, 1), 'Closed with explanation', 'Yes', 'Yes', 538136)
# (datetime.date(2013, 10, 5), 'Bank account or service', 'Checking account', 'Account opening, closing, or management', None, None, None, 'Wells Fargo & Company', 'CA', '92649', 'Older American', 'N/A', 'Web', datetime.date(2013, 10, 7), 'Closed with explanation', 'Yes', 'Yes', 553073)
# (datetime.date(2013, 9, 23), 'Mortgage', 'Conventional adjustable mortgage (ARM)', 'Loan modification,collection,foreclosure', None, None, None, 'Wells Fargo & Company', 'CA', '92626', None, 'N/A', 'Web', datetime.date(2013, 9, 24), 'Closed with explanation', 'Yes', 'No', 538994)
# (datetime.date(2013, 9, 27), 'Consumer Loan', 'Vehicle loan', 'Shopping for a loan or lease', None, None, None, 'Wells Fargo & Company', 'CA', '91752', None, 'N/A', 'Web', datetime.date(2013, 9, 30), 'Closed with explanation', 'Yes', 'No', 546221)
# (datetime.date(2013, 9, 23), 'Consumer Loan', 'Vehicle loan', 'Managing the loan or lease', None, None, None, 'Wells Fargo & Company', 'CA', '95823', None, 'N/A', 'Web', datetime.date(2013, 9, 25), 'Closed with explanation', 'Yes', 'No', 537960)
# (datetime.date(2013, 9, 28), 'Bank account or service', 'Checking account', 'Account opening, closing, or management', None, None, None, 'Wells Fargo & Company', 'CA', '92660', None, 'N/A', 'Web', datetime.date(2013, 9, 30), 'Closed with explanation', 'Yes', 'No', 546462)
# (datetime.date(2013, 9, 24), 'Mortgage', 'Conventional fixed mortgage', 'Loan servicing, payments, escrow account', None, None, None, 'Wells Fargo & Company', 'CA', '93002', 'Older American', 'N/A', 'Web', datetime.date(2013, 9, 24), 'Closed with explanation', 'Yes', 'Yes', 540879)
# (datetime.date(2013, 9, 29), 'Credit card', None, 'APR or interest rate', None, None, None, 'Wells Fargo & Company', 'CA', '91604', None, 'N/A', 'Web', datetime.date(2013, 9, 29), 'Closed', 'Yes', 'No', 545006)
# (datetime.date(2013, 10, 7), 'Mortgage', 'FHA mortgage', 'Settlement process and costs', None, None, None, 'Wells Fargo & Company', 'CA', '92503', None, 'N/A', 'Web', datetime.date(2013, 10, 8), 'Closed with explanation', 'Yes', 'No', 554096)
# (datetime.date(2013, 10, 16), 'Bank account or service', 'Checking account', 'Account opening, closing, or management', None, None, None, 'Wells Fargo & Company', 'CA', '92807', None, 'N/A', 'Phone', datetime.date(2013, 10, 17), 'Closed with non-monetary relief', 'Yes', 'No', 560689)
# (datetime.date(2013, 10, 17), 'Bank account or service', 'Checking account', 'Account opening, closing, or management', None, None, None, 'Wells Fargo & Company', 'CA', '95118', None, 'N/A', 'Phone', datetime.date(2013, 10, 17), 'Closed with monetary relief', 'Yes', 'No', 561094)
# (datetime.date(2013, 10, 23), 'Credit card', None, 'Credit card protection / Debt protection', None, None, None, 'Wells Fargo & Company', 'CA', '90808', None, 'N/A', 'Web', datetime.date(2013, 10, 23), 'Closed with explanation', 'Yes', 'No', 568791)
# (datetime.date(2013, 10, 23), 'Bank account or service', 'Checking account', 'Account opening, closing, or management', None, None, None, 'Wells Fargo & Company', 'CA', '91604', None, 'N/A', 'Web', datetime.date(2013, 10, 23), 'Closed with explanation', 'Yes', 'Yes', 569002)
# (datetime.date(2013, 10, 8), 'Mortgage', 'Conventional fixed mortgage', 'Loan modification,collection,foreclosure', None, None, None, 'Wells Fargo & Company', 'CA', '92626', None, 'N/A', 'Web', datetime.date(2013, 10, 9), 'Closed with explanation', 'Yes', 'No', 555484)
# (datetime.date(2013, 9, 30), 'Mortgage', 'Reverse mortgage', 'Loan servicing, payments, escrow account', None, None, None, 'Wells Fargo & Company', 'CA', '90059', None, 'N/A', 'Phone', datetime.date(2013, 10, 1), 'Closed with explanation', 'Yes', 'No', 547857)
# (datetime.date(2013, 11, 7), 'Bank account or service', 'Checking account', 'Deposits and withdrawals', None, None, None, 'Wells Fargo & Company', 'CA', '93729', None, 'N/A', 'Web', datetime.date(2013, 11, 7), 'Closed with explanation', 'Yes', 'No', 590592)
# (datetime.date(2013, 10, 24), 'Bank account or service', 'Checking account', 'Account opening, closing, or management', None, None, None, 'Wells Fargo & Company', 'CA', '90623', None, 'N/A', 'Phone', datetime.date(2013, 10, 25), 'Closed with explanation', 'Yes', 'No', 570025)
# (datetime.date(2013, 11, 8), 'Bank account or service', 'Checking account', 'Deposits and withdrawals', None, None, None, 'Wells Fargo & Company', 'CA', '90270', None, 'N/A', 'Referral', datetime.date(2013, 11, 13), 'Closed with explanation', 'Yes', 'No', 591346)
# (datetime.date(2013, 11, 8), 'Mortgage', 'FHA mortgage', 'Loan modification,collection,foreclosure', None, None, None, 'Wells Fargo & Company', 'CA', '92590', None, 'N/A', 'Web', datetime.date(2013, 11, 14), 'Closed with explanation', 'Yes', 'Yes', 590869)
# (datetime.date(2013, 11, 3), 'Student loan', 'Non-federal student loan', 'Repaying your loan', 'Repaying your loan', None, None, 'Wells Fargo & Company', 'CA', '92336', None, 'N/A', 'Web', datetime.date(2013, 11, 5), 'Closed with explanation', 'Yes', 'No', 582631)
# (datetime.date(2013, 11, 9), 'Bank account or service', 'Checking account', 'Making/receiving payments, sending money', None, None, None, 'Wells Fargo & Company', 'CA', '91740', None, 'N/A', 'Phone', datetime.date(2013, 11, 12), 'Closed with explanation', 'Yes', 'No', 591291)
# (datetime.date(2013, 11, 4), 'Bank account or service', 'Checking account', 'Account opening, closing, or management', None, None, None, 'Wells Fargo & Company', 'CA', '92065', None, 'N/A', 'Web', datetime.date(2013, 11, 4), 'Closed', 'Yes', 'No', 584538)
# (datetime.date(2013, 11, 9), 'Credit card', None, 'Identity theft / Fraud / Embezzlement', None, None, None, 'Wells Fargo & Company', 'CA', '94588', None, 'N/A', 'Web', datetime.date(2013, 11, 9), 'Closed with explanation', 'Yes', 'No', 592708)
# (datetime.date(2013, 10, 30), 'Mortgage', 'Conventional fixed mortgage', 'Settlement process and costs', None, None, None, 'Wells Fargo & Company', 'CA', '94523', None, 'N/A', 'Web', datetime.date(2013, 11, 8), 'Closed with explanation', 'Yes', 'Yes', 578296)
# (datetime.date(2013, 11, 12), 'Mortgage', 'Conventional fixed mortgage', 'Loan servicing, payments, escrow account', None, None, None, 'Wells Fargo & Company', 'CA', '92677', None, 'N/A', 'Web', datetime.date(2013, 11, 12), 'Closed with explanation', 'Yes', 'No', 593836)
# (datetime.date(2013, 10, 25), 'Bank account or service', 'Other bank product/service', 'Account opening, closing, or management', None, None, None, 'Wells Fargo & Company', 'CA', '91325', 'Servicemember', 'N/A', 'Web', datetime.date(2013, 10, 25), 'Closed with explanation', 'Yes', 'Yes', 571305)
# (datetime.date(2013, 10, 10), 'Mortgage', 'Conventional fixed mortgage', 'Loan modification,collection,foreclosure', None, None, None, 'Wells Fargo & Company', 'CA', '92626', None, 'N/A', 'Web', datetime.date(2013, 10, 11), 'Closed with explanation', 'Yes', 'No', 557320)
# (datetime.date(2013, 10, 10), 'Mortgage', 'Conventional fixed mortgage', 'Loan modification,collection,foreclosure', None, None, None, 'Wells Fargo & Company', 'CA', '94564', None, 'N/A', 'Web', datetime.date(2013, 10, 11), 'Closed with non-monetary relief', 'Yes', 'Yes', 557189)
# (datetime.date(2013, 10, 10), 'Mortgage', 'Other mortgage', 'Loan modification,collection,foreclosure', None, None, None, 'Wells Fargo & Company', 'CA', '91401', None, 'N/A', 'Referral', datetime.date(2013, 10, 15), 'Closed with explanation', 'Yes', 'No', 556681)
# (datetime.date(2013, 10, 10), 'Credit card', None, 'Billing disputes', None, None, None, 'Wells Fargo & Company', 'CA', '92570', None, 'N/A', 'Referral', datetime.date(2013, 10, 11), 'Closed with explanation', 'Yes', 'No', 557282)
# (datetime.date(2013, 10, 10), 'Mortgage', 'FHA mortgage', 'Loan modification,collection,foreclosure', None, None, None, 'Wells Fargo & Company', 'CA', '90732', None, 'N/A', 'Phone', datetime.date(2013, 10, 11), 'Closed with explanation', 'Yes', 'Yes', 557215)
# (datetime.date(2013, 11, 17), 'Mortgage', 'Conventional adjustable mortgage (ARM)', 'Loan modification,collection,foreclosure', None, None, None, 'Wells Fargo & Company', 'CA', '95070', None, 'N/A', 'Web', datetime.date(2013, 11, 16), 'Closed with explanation', 'Yes', 'No', 601487)
# (datetime.date(2013, 11, 21), 'Student loan', 'Non-federal student loan', 'Repaying your loan', 'Repaying your loan', None, None, 'Wells Fargo & Company', 'CA', '92882', None, 'N/A', 'Web', datetime.date(2013, 11, 22), 'Closed with explanation', 'Yes', 'No', 608309)
# (datetime.date(2013, 10, 11), 'Credit card', None, 'Advertising and marketing', None, None, None, 'Wells Fargo & Company', 'CA', '94523', None, 'N/A', 'Web', datetime.date(2013, 10, 11), 'Closed with explanation', 'Yes', 'No', 557839)
# (datetime.date(2013, 10, 25), 'Mortgage', 'Other mortgage', 'Loan modification,collection,foreclosure', None, None, None, 'Wells Fargo & Company', 'CA', '95833', None, 'N/A', 'Referral', datetime.date(2013, 10, 29), 'Closed with explanation', 'Yes', 'No', 571222)
# (datetime.date(2013, 10, 18), 'Mortgage', 'Home equity loan or line of credit', 'Loan servicing, payments, escrow account', None, None, None, 'Wells Fargo & Company', 'CA', '94509', 'Older American', 'N/A', 'Phone', datetime.date(2013, 10, 21), 'Closed with explanation', 'Yes', 'No', 563657)
# (datetime.date(2013, 10, 31), 'Mortgage', 'Conventional adjustable mortgage (ARM)', 'Loan modification,collection,foreclosure', None, None, None, 'Wells Fargo & Company', 'CA', '93636', None, 'N/A', 'Web', datetime.date(2013, 11, 4), 'Closed with explanation', 'Yes', 'No', 580069)
# (datetime.date(2013, 10, 25), 'Bank account or service', 'Checking account', 'Account opening, closing, or management', None, None, None, 'Wells Fargo & Company', 'CA', '93309', None, 'N/A', 'Phone', datetime.date(2013, 10, 28), 'Closed with explanation', 'Yes', 'No', 572405)
# (datetime.date(2013, 11, 22), 'Mortgage', 'Conventional fixed mortgage', 'Loan modification,collection,foreclosure', None, None, None, 'Wells Fargo & Company', 'CA', '90069', None, 'N/A', 'Web', datetime.date(2013, 11, 26), 'Closed with explanation', 'Yes', 'No', 609823)
# (datetime.date(2013, 11, 13), 'Mortgage', 'Conventional fixed mortgage', 'Application, originator, mortgage broker', None, None, None, 'Wells Fargo & Company', 'CA', '93401', None, 'N/A', 'Web', datetime.date(2013, 11, 12), 'Closed with explanation', 'Yes', 'No', 595687)
# (datetime.date(2013, 11, 13), 'Debt collection', 'Other (i.e. phone, health club, etc.)', "Cont'd attempts collect debt not owed", 'Debt is not mine', None, None, 'Wells Fargo & Company', 'CA', '94550', None, 'N/A', 'Web', datetime.date(2013, 11, 14), 'Closed with explanation', 'Yes', 'No', 595737)
# (datetime.date(2013, 11, 23), 'Mortgage', 'Other mortgage', 'Application, originator, mortgage broker', None, None, None, 'Wells Fargo & Company', 'CA', '90240', None, 'N/A', 'Referral', datetime.date(2013, 11, 25), 'Closed with explanation', 'Yes', 'No', 609428)
# (datetime.date(2013, 11, 23), 'Mortgage', 'Conventional fixed mortgage', 'Loan modification,collection,foreclosure', None, None, None, 'Wells Fargo & Company', 'CA', '93101', None, 'N/A', 'Web', datetime.date(2013, 11, 26), 'Closed with explanation', 'Yes', 'No', 609824)
# (datetime.date(2013, 11, 23), 'Mortgage', 'Conventional fixed mortgage', 'Loan modification,collection,foreclosure', None, None, None, 'Wells Fargo & Company', 'CA', '92655', None, 'N/A', 'Web', datetime.date(2013, 11, 23), 'Closed with explanation', 'Yes', 'Yes', 609512)
# (datetime.date(2013, 11, 23), 'Mortgage', 'Conventional fixed mortgage', 'Loan modification,collection,foreclosure', None, None, None, 'Wells Fargo & Company', 'CA', '92673', None, 'N/A', 'Web', datetime.date(2013, 11, 23), 'Closed with explanation', 'Yes', 'No', 609575)
# (datetime.date(2013, 10, 22), 'Bank account or service', 'Checking account', 'Account opening, closing, or management', None, None, None, 'Wells Fargo & Company', 'CA', '91331', None, 'N/A', 'Web', datetime.date(2013, 10, 22), 'Closed with explanation', 'Yes', 'Yes', 565853)
# (datetime.date(2013, 10, 22), 'Mortgage', 'Conventional fixed mortgage', 'Loan modification,collection,foreclosure', None, None, None, 'Wells Fargo & Company', 'CA', '91711', None, 'N/A', 'Web', datetime.date(2013, 10, 22), 'Closed with non-monetary relief', 'Yes', 'No', 565696)
# (datetime.date(2013, 10, 22), 'Mortgage', 'Other mortgage', 'Loan modification,collection,foreclosure', None, None, None, 'Wells Fargo & Company', 'CA', '95204', None, 'N/A', 'Web', datetime.date(2013, 10, 22), 'Closed with explanation', 'Yes', 'No', 565673)
# (datetime.date(2013, 10, 31), 'Bank account or service', 'Checking account', 'Deposits and withdrawals', None, None, None, 'Wells Fargo & Company', 'CA', '92008', None, 'N/A', 'Phone', datetime.date(2013, 11, 4), 'Closed with explanation', 'Yes', 'No', 580448)
# (datetime.date(2013, 11, 25), 'Mortgage', 'Other mortgage', 'Loan modification,collection,foreclosure', None, None, None, 'Wells Fargo & Company', 'CA', '90047', 'Older American', 'N/A', 'Fax', datetime.date(2013, 11, 25), 'Closed with explanation', 'Yes', 'Yes', 611771)
# (datetime.date(2013, 10, 22), 'Mortgage', 'Conventional fixed mortgage', 'Loan modification,collection,foreclosure', None, None, None, 'Wells Fargo & Company', 'CA', '92590', None, 'N/A', 'Web', datetime.date(2013, 10, 24), 'Closed with explanation', 'Yes', 'Yes', 565708)
# (datetime.date(2013, 10, 23), 'Mortgage', 'Conventional fixed mortgage', 'Loan modification,collection,foreclosure', None, None, None, 'Wells Fargo & Company', 'CA', '95827', 'Older American', 'N/A', 'Web', datetime.date(2013, 10, 23), 'Closed with explanation', 'Yes', 'No', 567819)
# (datetime.date(2013, 11, 25), 'Bank account or service', 'Other bank product/service', 'Account opening, closing, or management', None, None, None, 'Wells Fargo & Company', 'CA', '90277', None, 'N/A', 'Web', datetime.date(2013, 11, 25), 'Closed with explanation', 'Yes', 'Yes', 610816)
# (datetime.date(2013, 11, 19), 'Mortgage', 'Conventional adjustable mortgage (ARM)', 'Settlement process and costs', None, None, None, 'Wells Fargo & Company', 'CA', '94002', None, 'N/A', 'Web', datetime.date(2013, 12, 2), 'Closed with explanation', 'Yes', 'No', 604295)
# (datetime.date(2013, 11, 1), 'Mortgage', 'Conventional adjustable mortgage (ARM)', 'Loan servicing, payments, escrow account', None, None, None, 'Wells Fargo & Company', 'CA', '92262', None, 'N/A', 'Postal mail', datetime.date(2013, 11, 5), 'Closed with explanation', 'Yes', 'No', 581909)
# (datetime.date(2013, 11, 20), 'Credit card', None, 'Transaction issue', None, None, None, 'Wells Fargo & Company', 'CA', '95010', None, 'N/A', 'Web', datetime.date(2013, 11, 20), 'Closed with explanation', 'Yes', 'No', 605425)
# (datetime.date(2013, 11, 20), 'Bank account or service', 'Savings account', 'Deposits and withdrawals', None, None, None, 'Wells Fargo & Company', 'CA', '92672', None, 'N/A', 'Referral', datetime.date(2013, 11, 20), 'Closed', 'Yes', 'No', 606171)
# (datetime.date(2013, 11, 1), 'Mortgage', 'Conventional fixed mortgage', 'Loan modification,collection,foreclosure', None, None, None, 'Wells Fargo & Company', 'CA', '91311', None, 'N/A', 'Web', datetime.date(2013, 11, 14), 'Closed with explanation', 'Yes', 'Yes', 582150)
# (datetime.date(2013, 11, 14), 'Mortgage', 'Conventional fixed mortgage', 'Loan modification,collection,foreclosure', None, None, None, 'Wells Fargo & Company', 'CA', '92626', None, 'N/A', 'Web', datetime.date(2013, 11, 27), 'Closed with explanation', 'Yes', 'No', 597307)
# (datetime.date(2013, 11, 14), 'Mortgage', 'Other mortgage', 'Loan modification,collection,foreclosure', None, None, None, 'Wells Fargo & Company', 'CA', '91710', None, 'N/A', 'Web', datetime.date(2013, 11, 13), 'Closed with explanation', 'Yes', 'No', 598153)
# (datetime.date(2013, 11, 7), 'Mortgage', 'Other mortgage', 'Loan modification,collection,foreclosure', None, None, None, 'Wells Fargo & Company', 'CA', '94568', None, 'N/A', 'Fax', datetime.date(2013, 11, 8), 'Closed with explanation', 'Yes', 'No', 589105)
# (datetime.date(2013, 11, 7), 'Mortgage', 'Other mortgage', 'Loan modification,collection,foreclosure', None, None, None, 'Wells Fargo & Company', 'CA', '95670', None, 'N/A', 'Referral', datetime.date(2013, 11, 8), 'Closed with explanation', 'Yes', 'Yes', 590362)
# (datetime.date(2013, 12, 3), 'Mortgage', 'Other mortgage', 'Loan modification,collection,foreclosure', None, None, None, 'Wells Fargo & Company', 'CA', '95386', None, 'N/A', 'Fax', datetime.date(2014, 6, 18), 'Closed with explanation', 'Yes', 'No', 618849)
# (datetime.date(2013, 11, 7), 'Bank account or service', 'Checking account', 'Account opening, closing, or management', None, None, None, 'Wells Fargo & Company', 'CA', '91340', None, 'N/A', 'Web', datetime.date(2013, 11, 7), 'Closed with explanation', 'Yes', 'No', 589689)
# ...
# (datetime.date(2015, 5, 15), 'Bank account or service', 'Savings account', 'Deposits and withdrawals', None, None, None, 'Wells Fargo & Company', 'CA', '90045', None, 'N/A', 'Phone', datetime.date(2015, 5, 15), 'Closed with explanation', 'Yes', 'Yes', 1377189)
# (datetime.date(2015, 5, 15), 'Student loan', 'Non-federal student loan', "Can't repay my loan", "Can't get flexible payment options", 'I have a private student loan through Wells Fargo that was originally {$12000.00}. I started paying on the loan in 2012 which was then 18,000. I, being a young, " not so intelligent \'\' person at the time did n\'t realize interest was accruing from the time I got the loan nor did I expect it to be as high as it is. I have now paid over {$5000.00} on the loan and about {$900.00} has gone to principal, the rest interest. The loan has an interest rate of over 11 %. I have tried time and again to get the rate reduced, or even my monthly bill reduced and they will not help me at ALL! I do have some credit issues that I have been dealing with for the past couple of years and recently had to file for bankruptcy. I am in the process of rebuilding my credit and I am really trying to get my finances in order. Wells Fargo has made it very difficult for me to make any progress, they continue to ignore my pleads for any kind of help and repeatedly tell me that they can not help me. I understand that I am responsible for this debt. I am fully ready to take responsibility, but I also believe there in no reason someone who makes less than XXXX a year should be paying that high of an interest rate let alone a {$200.00} a month payment. I have done my research and there are not a lot of options for someone in my position, I am hoping filing this complaint will give me some more insight on what else I can do. At this rate, I will be paying on this loan for years to come. Please give me some direction. It would be greatly appreciated!', 'Company chooses not to provide a public response', 'Wells Fargo & Company', 'CA', '921XX', None, 'Consent provided', 'Web', datetime.date(2015, 5, 15), 'Closed with explanation', 'Yes', 'No', 1377366)
# (datetime.date(2015, 5, 15), 'Mortgage', 'Conventional fixed mortgage', 'Loan servicing, payments, escrow account', None, 'I received notice from our Mortgagor on XXXX dated XXXX stating they did not have evidence of hazard insurance coverage. Per request on XXXX, I sent a copy of XXXX XXXX Declarations Page showing current coverage from XX/XX/XXXX through XX/XX/XXXX. On XXXX I received notice from Mortgagor dated XXXX saying that unless they had evidence of hazard insurance Mortgagor would buy the insurance and charge me through an increase in escrow of {$390.00} per month for a policy substantially more expensive than my existing policy. Per instructions, I entered the information regarding existing hazard insurance on XXXX ( which actually in a confusing manner had pre-entered the Mortgagor \'s more expensive coverage with XXXX XXXX XXXX XXXX. On XXXX I talked with a Customer Service Representative of the Mortgagor. ( I can provide name. ) She indicated that Mortgagor did have the information that proved we had current hazard insurance. I asked for a confirming email and was told she was prohibited from sending such an email. She instead initiated a written letter that I subsequently received dated XXXX confirming that the Mortgagor had received evidence of current coverage and that we could disregard the " notice of insurance expiration sent to you previously. \'\' I also received a second letter from the Mortgagor dated XXXX thanking us for providing coverage evidence and assuring us we were not charged " for the temporary coverage \'\'. \n\nI confirmed with my insurance agent that the agent had notified the Mortgagor upon expiration of the previous coverage on XX/XX/XXXX that new coverage was in effect from that date through XX/XX/XXXX. The agent can, if required, provide evidence of this notification. The agent also actually received from the Mortgagor a payment of {$160.00} from our escrow account to cover a premium increase that we authorized in order to avoid a substantial increase in the policy deductible. Thus, not only had the Mortgagor received multiple notifications of our current insurance but the Mortgagor acknowledged such and acted in accordance with the knowledge by paying our Insurance premium increase. \n\nNevertheless, by letter dated XX/XX/XXXX we received a loan statement. It acknowledged receiving our payment of {$1300.00} on XXXX and also said our payment due XXXX XXXX, would be {$1700.00}. We also received an " Escrow account disclosure statement and notice of new mortgage payment. \'\' It shows an escrow shortage of {$3200.00} and an increased payment starting XXXX XXXX to {$780.00} because of projected payments for insurance purchased by the Mortgagor to XXXX XXXX XXXX. This is despite the specific listing in the statement itself of the above-referenced {$160.00} to our insurer for the increased premium on our current insurance. \n\nI called the Mortgagor on XX/XX/XXXX. I spoke to a Customer Service Representative who referred me to another representative in the Insurance Dept. who then referred me to yet another in the Escrow Dept. who referred me to still another in the Executive Dept.. ( For the first XXXX I had to repeat various ID information. ) The last XXXX agreed to send me a letter confirming that we now had a slight overage in our escrow account and that our payment for XXXX would be {$1300.00} and for XXXX would be {$1300.00}. She said she was prohibited from confirming this by email but a letter would go out at the latest on XXXX. \n\nThis entire experience appears like it is almost designed to confuse senior mortgagees and trick them into agreeing to more expensive insurance linked to the Mortgagor. In some cases it would not even surprise us that mortgagees have been unwittingly duped into agreeing to unnecessary double coverage.', 'Company chooses not to provide a public response', 'Wells Fargo & Company', 'CA', '958XX', 'Older American', 'Consent provided', 'Web', datetime.date(201 ...
# (datetime.date(2015, 5, 15), 'Money transfers', 'International money transfer', 'Other transaction issues', None, 'I have been a victim of fraud and I want to stop the money from going thru. \n', 'Company chooses not to provide a public response', 'Wells Fargo & Company', 'CA', '933XX', 'Servicemember', 'Consent provided', 'Web', datetime.date(2015, 5, 15), 'Closed with explanation', 'Yes', 'No', 1377424)
# (datetime.date(2015, 5, 6), 'Bank account or service', 'Checking account', 'Using a debit or ATM card', None, "The bank decided to cancel my debit card without notifying me. I just had XXXX 5 days ago and my father has been helping me out by going to the super market and purchasing food for my XXXX children. Yesterday XXXX/XXXX/14 he went to the store and my card was decline. I checked my account and had enough funds to purchase our diner. I called customer service and was told that my debit card was cancel because if was good for 3 weeks until I received my new cars. Well I never received a new card and my old XXXX was cancel. The associate said it would take XXXX-8 days to receive the new card, I asked if they could Rush my card and the associate places me on hold to ask her manager and was advise that they could not rush my card because they do n't have the ability. I ask to speak to the manager and the associate gave me so much push back. She finally transfer me to XXXX XXXX XXXX, and he again asked me to go to the branch after I told him I could n't walk because I just had XXXX. I have been descriminated numerous times by Wells Fargo Bank because of the type of account I have. If I would have been told that having an opportunity account meant that I would be charge fees when ever they felt like it or reject my request to cash a 16 dollar check I would had never open this acxount. It 's so unfair that I have to wait 8 days to spend my money because the bank could n't Rush my new debit card. I want a formal apology and a reason why they could n't Rush my debit card. Why do I get discriminated so much? I am hurt and feel horrible by all the abuse I have accounted by Wells Fargo. This bank should not be allowed to discriminated customers based on their account type! Wether I am poor or rich I have the right to be treated fair.", None, 'Wells Fargo & Company', 'CA', '914XX', None, 'Consent provided', 'Web', datetime.date(2015, 5, 6), 'Closed with explanation', 'Yes', 'No', 1362941)
# (datetime.date(2015, 5, 26), 'Mortgage', 'Conventional fixed mortgage', 'Loan modification,collection,foreclosure', None, None, 'Company chooses not to provide a public response', 'Wells Fargo & Company', 'CA', '94568', None, 'Consent not provided', 'Web', datetime.date(2015, 5, 26), 'Closed with explanation', 'Yes', 'No', 1392201)
# (datetime.date(2015, 4, 21), 'Student loan', 'Non-federal student loan', "Can't repay my loan", "Can't get flexible payment options", None, None, 'Wells Fargo & Company', 'CA', '92116', None, 'Consent not provided', 'Web', datetime.date(2015, 4, 21), 'Closed with explanation', 'Yes', 'No', 1340051)
# (datetime.date(2015, 4, 27), 'Credit card', None, 'Identity theft / Fraud / Embezzlement', None, 'I found that Wells Fargo reported to a credit reporting agency that I owed them a debt of {$420.00} on XXXX 2012 on a credit card account. I never opened a credit card account with Wells Fargo and have no knowledge of any credit card charges made on a Wells Fargo credit card in my name. I wrote to Wells Fargo and informed them of these facts. I also told Wells Fargo that I believed that these charges were fraudulent and suspected that I had been a victim of identity theft. I requested that Wells Fargo conduct an investigation into the matter and that Wells Fargo provide to me all account documents and billing statements related to this claimed debt so that I could determine whether I had been a victim of identity theft as I suspected. Wells Fargo responded but refused my request for documentation and its response does not indicate that it conducted any investigation into my claim that I had been the victim of credit card fraud and identity theft.', None, 'Wells Fargo & Company', 'CA', '941XX', None, 'Consent provided', 'Web', datetime.date(2015, 4, 27), 'Closed with explanation', 'Yes', 'Yes', 1348201)
# (datetime.date(2015, 5, 20), 'Debt collection', 'Mortgage', 'Disclosure verification of debt', 'Not given enough info to verify debt', None, 'Company chooses not to provide a public response', 'Wells Fargo & Company', 'CA', '90262', None, 'N/A', 'Referral', datetime.date(2015, 5, 26), 'Closed with explanation', 'Yes', 'No', 1384972)
# (datetime.date(2015, 4, 27), 'Consumer Loan', 'Vehicle loan', 'Problems when you are unable to pay', None, 'Two weeks ago I contacted Wells Fargo because I am late on my car payment. At that time the car payment was approximately 45 or so days late ( actually I do n\'t know the exact # because Wells Fargo would n\'t tell me ) but as of today I was notified of a 60 day late on my credit report. I tried to make a payment with Wells Fargo but they would not take it. I believe they wanted XXXX payments which at that time I was unable to do that but I was willing to set up a payment XXXX for the XXXX and XXXX for the XXXX which is coming up. They refused. I hung up and called back thinking I might get someone willing to work with me. They transferred me to a Manager and he said he was the only person I could talk to and he was not working with me. ( not in those exact words ) but he showed no interest in working with me or taking my payment. ( Fast forward ). I have a XXXX car garage ( tandem ; XXXX car in front XXXX in back ) but I ca n\'t close the garage because I have items in the front spot so XXXX car sticks out. The Manager never mentioned anything about repo and my intention was to pay the back payments this Thursday the XXXX so my intent was not to hide the car because if it were I would have parked my other car on the street and closed the garage. I park this way all the time because XXXX cars can not go all the way into the garage. Well Friday XXXX at XXXX someone came banging on my door yelling for me to give him the car. I was at home alone therefor I did not open the door. My Jetta was blocking the Toyota so the only way for him to have seen the car was to enter the garage. He continued to bang on the door making loud noises and when I finally opened the back door he was sitting in his truck blocking my garage and blocking my other car. I asked him to leave and he refused stating " he will sit there all night \'\' he was disturbing the neighbors with the yelling and the loud noise from his truck. I eventually had to call the Sheriff \'s to get him to leave. I am not sure but I could swear that the voice was the same voice of the manager I spoke with on the phone a couple of weeks ago. In my opinion it seems as though Wells Fargo employees are getting kick backs for repossessing customers cars because the voice sounded the same as the manager that would not work with me. Please investigate this because if that is what they are doing Wells Fargo needs to be aware of this practice. Also, I am not sure if a repo man can come bang on your door at XXXX and demand that you give him the car. I do n\'t know the rules .I want to call Wells Fargo to try and work something out but I am afraid that that same person will answer the phone. I simply want to know my options so I can decide if I want to keep the car or turn it in. In addition Wells Fargo put insurance on the loan for a month but have spread the payments over the deration of the loan ; meaning I am paying 13 % interest on the insurance because I am paying 13 % interest on the loan. It \'s bad enough that the car only cost XXXX and I have been paying it since 2011 and I still owe XXXX. And they would not work with me to rewrite the loan when I asked, when it was current.', 'Company chooses not to provide a public response', 'Wells Fargo & Company', 'CA', '913XX', None, 'Consent provided', 'Web', datetime.date(2015, 4, 27), 'Closed with explanation', 'Yes', 'No', 1348308)
# (datetime.date(2015, 5, 6), 'Mortgage', 'Other mortgage', 'Loan servicing, payments, escrow account', None, None, None, 'Wells Fargo & Company', 'CA', '92124', None, 'N/A', 'Referral', datetime.date(2015, 5, 7), 'Closed with explanation', 'Yes', 'No', 1362371)
# CPU times: user 32.6 ms, sys: 11.3 ms, total: 43.9 ms
# Wall time: 75.3 ms

# %%
# %%time
df1[
    (df1['State Name'] == df1[(df1['Company'] == company) & 
                              (df1['State Name'].notnull())
                             ].groupby(['State Name'])[['Issue']].count().idxmax()[0])
    & (df1['Company'] == company)]
# Out:
# CPU times: user 21.7 ms, sys: 1.95 ms, total: 23.6 ms
# Wall time: 22 ms
#       Date Received             Product Name                  Sub Product  \
# 1        2013-07-29  Bank account or service             Checking account
# 27       2013-07-29  Bank account or service   Other bank product/service
# 51       2013-07-29  Bank account or service             Checking account
# 54       2013-07-29                 Mortgage  Conventional fixed mortgage
# 80       2013-07-29                 Mortgage               Other mortgage
# ...             ...                      ...                          ...
# 65381    2015-05-26                 Mortgage  Conventional fixed mortgage
# 65394    2015-04-27              Credit card                          NaN
# 65426    2015-05-20          Debt collection                     Mortgage
# 65463    2015-04-27            Consumer Loan                 Vehicle loan
# 65483    2015-05-06                 Mortgage               Other mortgage
#
#                                           Issue  \
# 1                     Using a debit or ATM card
# 27                     Deposits and withdrawals
# 51                     Deposits and withdrawals
# 54     Loan modification,collection,foreclosure
# 80     Loan modification,collection,foreclosure
# ...                                         ...
# 65381  Loan modification,collection,foreclosure
# 65394     Identity theft / Fraud / Embezzlement
# 65426           Disclosure verification of debt
# 65463       Problems when you are unable to pay
# 65483  Loan servicing, payments, escrow account
#
#                                   Sub Issue  \
# 1                                       NaN
# 27                                      NaN
# 51                                      NaN
# 54                                      NaN
# 80                                      NaN
# ...                                     ...
# 65381                                   NaN
# 65394                                   NaN
# 65426  Not given enough info to verify debt
# 65463                                   NaN
# 65483                                   NaN
#
#                             Consumer Complaint Narrative  \
# 1                                                    NaN
# 27                                                   NaN
# 51                                                   NaN
# 54                                                   NaN
# 80                                                   NaN
# ...                                                  ...
# 65381                                                NaN
# 65394  I found that Wells Fargo reported to a credit ...
# 65426                                                NaN
# 65463  Two weeks ago I contacted Wells Fargo because ...
# 65483                                                NaN
#
#                                 Company Public Response  \
# 1                                                   NaN
# 27                                                  NaN
# 51                                                  NaN
# 54                                                  NaN
# 80                                                  NaN
# ...                                                 ...
# 65381  Company chooses not to provide a public response
# 65394                                               NaN
# 65426  Company chooses not to provide a public response
# 65463  Company chooses not to provide a public response
# 65483                                               NaN
#
#                      Company State Name Zip Code            Tags  \
# 1      Wells Fargo & Company         CA    95992  Older American
# 27     Wells Fargo & Company         CA    96088             NaN
# 51     Wells Fargo & Company         CA    92277             NaN
# 54     Wells Fargo & Company         CA    91741             NaN
# 80     Wells Fargo & Company         CA    95020             NaN
# ...                      ...        ...      ...             ...
# 65381  Wells Fargo & Company         CA    94568             NaN
# 65394  Wells Fargo & Company         CA    941XX             NaN
# 65426  Wells Fargo & Company         CA    90262             NaN
# 65463  Wells Fargo & Company         CA    913XX             NaN
# 65483  Wells Fargo & Company         CA    92124             NaN
#
#       Consumer Consent Provided Submitted via Date Sent to Company  \
# 1                           NaN           Web           2013-07-31
# 27                          NaN           Web           2013-08-01
# 51                          NaN           Web           2013-08-05
# 54                          NaN         Phone           2013-07-30
# 80                          NaN      Referral           2013-07-31
# ...                         ...           ...                  ...
# 65381      Consent not provided           Web           2015-05-26
# 65394          Consent provided           Web           2015-04-27
# 65426                       NaN      Referral           2015-05-26
# 65463          Consent provided           Web           2015-04-27
# 65483                       NaN      Referral           2015-05-07
#
#       Company Response to Consumer Timely Response Consumer Disputed  \
# 1          Closed with explanation             Yes                No
# 27         Closed with explanation             Yes                No
# 51         Closed with explanation             Yes                No
# 54         Closed with explanation             Yes                No
# 80         Closed with explanation             Yes                No
# ...                            ...             ...               ...
# 65381      Closed with explanation             Yes                No
# 65394      Closed with explanation             Yes               Yes
# 65426      Closed with explanation             Yes                No
# 65463      Closed with explanation             Yes                No
# 65483      Closed with explanation             Yes                No
#
#        Complaint ID
# 1            468889
# 27           469185
# 51           469446
# 54           464039
# 80           469660
# ...             ...
# 65381       1392201
# 65394       1348201
# 65426       1384972
# 65463       1348308
# 65483       1362371
#
# [776 rows x 18 columns]
